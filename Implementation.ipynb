# %%
from keras.models import load_model
import cv2
import numpy as np
from playsound import playsound

# %%
pip install playsound
# Out:
# Requirement already satisfied: playsound in c:\users\asus\anaconda3\lib\site-packages (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
model = load_model('model-002.model')

face_clsfr=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

source=cv2.VideoCapture(0)

labels_dict={1:'MASK',0:'NO MASK'}
color_dict={1:(0,255,0),0:(0,0,255)}

# %%
import threading

while(True):

    ret,img=source.read()
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=face_clsfr.detectMultiScale(gray,1.3,5)  

    for (x,y,w,h) in faces:
    
        face_img=gray[y:y+w,x:x+w]
        
        resized=cv2.resize(face_img,(100,100))
        normalized=resized/255.0
        reshaped=np.reshape(normalized,(1,100,100,1))
        result=model.predict(reshaped)

        label=np.argmax(result,axis=1)[0]
        if(label==0):
            threading.Thread(target = playsound, args = ('C:\\Users\\ASUS\\Documents\\PC\\College\\Events\\DROID 2.0\\Mask-detection\\beep.mp3', ), daemon = True).start()
            
      
        cv2.rectangle(img,(x,y),(x+w,y+h),color_dict[label],2)
        cv2.rectangle(img,(x,y-40),(x+w,y),color_dict[label],-1)
        cv2.putText(img, labels_dict[label], (x, y-10),cv2.FONT_HERSHEY_SIMPLEX,0.8,(255,255,255),2)
        
        
    cv2.imshow('FAce detection',img)
    key=cv2.waitKey(1)
    
    if(key==27):
        break
        
cv2.destroyAllWindows()
source.release()
# Out:
#     Error 259 for command:
#         play "C:\Users\ASUS\AppData\Local\Temp\PSg31x4iy5.mp3" wait
#     The driver cannot recognize the specified command parameter.
#
#     Error 259 for command:
#         play "C:\Users\ASUS\AppData\Local\Temp\PS28nxioeu.mp3" wait
#     The driver cannot recognize the specified command parameter.
#
#     Error 305 for command:
#         close "C:\Users\ASUS\AppData\Local\Temp\PSg31x4iy5.mp3"
#     Cannot specify extra characters after a string enclosed in quotation marks.
#
#     Error 305 for command:
#         close "C:\Users\ASUS\AppData\Local\Temp\PS28nxioeu.mp3"
#     Cannot specify extra characters after a string enclosed in quotation marks.
# Failed to close the file: "C:\Users\ASUS\AppData\Local\Temp\PSg31x4iy5.mp3"
# Exception in thread Failed to close the file: "C:\Users\ASUS\AppData\Local\Temp\PS28nxioeu.mp3"
# Thread-91:
# Traceback (most recent call last):
#   File "C:\Users\ASUS\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
# Exception in thread Thread-93:
# Traceback (most recent call last):
#   File "C:\Users\ASUS\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\ASUS\anaconda3\lib\threading.py", line 910, in run
#     self.run()
#   File "C:\Users\ASUS\anaconda3\lib\threading.py", line 910, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 44, in _playsoundWin
#     _playsoundWin(tempPath, block)
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 73, in _playsoundWin
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 44, in _playsoundWin
#     winCommand(u'play {}{}'.format(sound, ' wait' if block else ''))
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 64, in winCommand
#     _playsoundWin(tempPath, block)
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 73, in _playsoundWin
#     raise PlaysoundException(exceptionMessage)
# playsound.PlaysoundException:
#     Error 259 for command:
#         play "C:\Users\ASUS\AppData\Local\Temp\PSg31x4iy5.mp3" wait
#     The driver cannot recognize the specified command parameter.
#     winCommand(u'play {}{}'.format(sound, ' wait' if block else ''))
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 64, in winCommand
#     raise PlaysoundException(exceptionMessage)
# playsound.PlaysoundException:
#     Error 259 for command:
#         play "C:\Users\ASUS\AppData\Local\Temp\PS28nxioeu.mp3" wait
#     The driver cannot recognize the specified command parameter.
#
#     Error 259 for command:
#         play "C:\Users\ASUS\AppData\Local\Temp\PSxa1cj0xn.mp3" wait
#     The driver cannot recognize the specified command parameter.
#
#     Error 259 for command:
#         play "C:\Users\ASUS\AppData\Local\Temp\PSdqpq3x83.mp3" wait
#     The driver cannot recognize the specified command parameter.
#
#     Error 259 for command:
#         play "C:\Users\ASUS\AppData\Local\Temp\PS1b1mzp2w.mp3" wait
#     The driver cannot recognize the specified command parameter.
#
#     Error 259 for command:
#         play "C:\Users\ASUS\AppData\Local\Temp\PSw7stxhry.mp3" wait
#     The driver cannot recognize the specified command parameter.
#
#     Error 305 for command:
#         close "C:\Users\ASUS\AppData\Local\Temp\PSxa1cj0xn.mp3"
#     Cannot specify extra characters after a string enclosed in quotation marks.
#
#     Error 305 for command:
#         close "C:\Users\ASUS\AppData\Local\Temp\PSdqpq3x83.mp3"
#     Cannot specify extra characters after a string enclosed in quotation marks.
#
#     Error 305 for command:
#         close "C:\Users\ASUS\AppData\Local\Temp\PS1b1mzp2w.mp3"
#     Cannot specify extra characters after a string enclosed in quotation marks.
# Failed to close the file: "C:\Users\ASUS\AppData\Local\Temp\PSxa1cj0xn.mp3"
# Exception in thread Failed to close the file: "C:\Users\ASUS\AppData\Local\Temp\PSdqpq3x83.mp3"
# Thread-103:
# Traceback (most recent call last):
#   File "C:\Users\ASUS\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
# Exception in thread Thread-96:
# Traceback (most recent call last):
#   File "C:\Users\ASUS\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
# Failed to close the file: "C:\Users\ASUS\AppData\Local\Temp\PS1b1mzp2w.mp3"
# Exception in thread Thread-100:
# Traceback (most recent call last):
#   File "C:\Users\ASUS\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\ASUS\anaconda3\lib\threading.py", line 910, in run
# Exception in thread Thread-98:
# Traceback (most recent call last):
#   File "C:\Users\ASUS\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\ASUS\anaconda3\lib\threading.py", line 910, in run
#     self.run()
# self.run()
#   File "C:\Users\ASUS\anaconda3\lib\threading.py", line 910, in run
#   File "C:\Users\ASUS\anaconda3\lib\threading.py", line 910, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 44, in _playsoundWin
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 44, in _playsoundWin
#         self._target(*self._args, **self._kwargs)
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 44, in _playsoundWin
# _playsoundWin(tempPath, block)
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 73, in _playsoundWin
#     _playsoundWin(tempPath, block)
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 73, in _playsoundWin
#         self._target(*self._args, **self._kwargs)
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 44, in _playsoundWin
# _playsoundWin(tempPath, block)
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 73, in _playsoundWin
#     winCommand(u'play {}{}'.format(sound, ' wait' if block else ''))
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 64, in winCommand
#     winCommand(u'play {}{}'.format(sound, ' wait' if block else ''))
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 64, in winCommand
#     _playsoundWin(tempPath, block)
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 73, in _playsoundWin
#     winCommand(u'play {}{}'.format(sound, ' wait' if block else ''))
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 64, in winCommand
#     winCommand(u'play {}{}'.format(sound, ' wait' if block else ''))
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\playsound.py", line 64, in winCommand
#     raise PlaysoundException(exceptionMessage)
# playsound.PlaysoundException:
#     Error 259 for command:
#         play "C:\Users\ASUS\AppData\Local\Temp\PSw7stxhry.mp3" wait
#     The driver cannot recognize the specified command parameter.
#     raise PlaysoundException(exceptionMessage)
# playsound.PlaysoundException:
#     Error 259 for command:
#         play "C:\Users\ASUS\AppData\Local\Temp\PSdqpq3x83.mp3" wait
#     The driver cannot recognize the specified command parameter.
#     raise PlaysoundException(exceptionMessage)
# playsound.PlaysoundException:
#     Error 259 for command:
#         play "C:\Users\ASUS\AppData\Local\Temp\PSxa1cj0xn.mp3" wait
#     The driver cannot recognize the specified command parameter.
#     raise PlaysoundException(exceptionMessage)
# playsound.PlaysoundException:
#     Error 259 for command:
#         play "C:\Users\ASUS\AppData\Local\Temp\PS1b1mzp2w.mp3" wait
#     The driver cannot recognize the specified command parameter.
